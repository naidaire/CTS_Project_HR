# %% [markdown]
# # Data Visualization Project
#
# Open:FactSet Insights and Analysis team.
#
# The team mission is to educate, inspire, and empower FactSetters and clients to utilize Open:FactSet Data and Solutions.
#
# As part of the team you will be tasked with creating and communicating compelling stories for Marketplace content.  Secondarily, the team collective will need to develop best practices and methods for disseminating knowledge both internally and externally.  For the interview please prepare a 20-30 minute presentation covering:
#
# 1. For an audience of CTS Sales, create a presentation showcasing a FactSet content set using Python, R, or SQL.  The goal is to educate on potential applications, how a given technology is applied and how to pitch this to their client base.
#     - Python, Jupyter Notebook, Ondemand?,
#     - Unique Datasets - RBICs + ESG Data
#     - Exploratory Data Analysis
#     - Hans Rosling Chart

# %%
from pathlib import Path

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

#Increase default figure and font sizes for easier viewing.
plt.rcParams['figure.figsize'] = (16, 9)
plt.rcParams['font.size'] = 14

plt.style.use('fivethirtyeight')

# %%
data  = Path('.', 'assets', 'rbics_esg_data.csv')
hans_rosling = pd.read_csv(data, na_values= '-')

# %%
hans_rosling = hans_rosling.dropna()

# %%
# RBICS Econonmic Focus Color Map 
# source:  https://matplotlib.org/2.0.2/examples/color/named_colors.html

econ_color_dict = {
    'Non-Energy Materials': 'black', 
    'Industrials': 'white', 
    'Healthcare': 'gray', 
    'Technology': 'red',
    'Consumer Cyclicals': 'orange', 
    'Utilities': 'yellow', 
    'Finance': 'green',
    'Consumer Non-Cyclicals': 'blue', 
    'Energy': 'indigo', 
    'Telecommunications': 'violet',
    'Business Services': 'pink', 
    'Consumer Services': 'chocolate'
    
}

# %%
# RBICS Sector Focus Color Map
# source:  https://matplotlib.org/2.0.2/examples/color/named_colors.html

sect_color_dict = {
    'Manufactured Products': 'black', 
    'Industrial Manufacturing': 'white',
    'Healthcare Equipment': 'lightgray', 
    'Biopharmaceuticals': 'gray',
    'Software and Consulting': 'red', 
    'Miscellaneous Retail': 'darkorange',
    'Electronic Components and Manufacturing': 'darkred', 
    'Utilities': 'yellow',
    'Healthcare Services': 'silver', 
    'Investment Services': 'lawngreen', 
    'Insurance': 'green',
    'Chemical, Plastic and Rubber Materials': 'k', 
    'Real Estate': 'seagreen',
    'Mining and Mineral Products': 'dimgray', 
    'Specialty Finance and Services': 'darkolivegreen',
    'Food and Tobacco Production': 'blue', 
    'Food and Staples Retail': 'dodgerblue',
    'Industrial Services': 'whitesmoke', 
    'Upstream Energy': 'indigo',
    'Downstream and Midstream Energy': 'blueviolet', 
    'Hardware': 'firebrick',
    'Consumer Vehicles and Parts': 'peachpuff', 
    'Telecommunications': 'violet',
    'Business Services': 'pink', 
    'Banking': 'forestgreen', 
    'Consumer Retail': 'orange',
    'Hospitality Services': 'sienna', 
    'Media and Publishing Services': 'saddlebrown',
    'Household Products': 'navy', 
    'Household Services': 'royalblue',
    'Consumer Goods': 'sandybrown'
    
}

# %%
# Sum ESG Scores for Environment + Social + Government
hans_rosling.loc[:, 'rbics_sect_color'] = hans_rosling.loc[:, 'rbics_sect'].map(sect_color_dict)
hans_rosling.loc[:, 'esg_combined'] = hans_rosling.loc[:, ['msci_esg_env','msci_esg_social', 'msci_esg_gov']].sum(axis=1)

# %%
def hans_rosling_date_and_rbics(year, econ):
    #Define a function that creates a scatter plot based on x = esg_score, y = sales_total, size = mkt_val, color = rbics_sector
    #Filter by date and rbics econ
    
    # Define a function that filters the dataframe by date    
    date_filter = hans_rosling.loc[:, 'Date'] == year
    hans_rosling_year = hans_rosling.loc[date_filter, :]
    
    # filter by rbics_sect
    rbics_filter = hans_rosling_year.loc[:, 'rbics_econ'] == econ
    hans_rosling_year_and_rbics = hans_rosling_year.loc[rbics_filter, :]
    
    
    #store values into array variables for scatter plot
    esg_score = hans_rosling_year_and_rbics.loc[:, 'esg_combined']
    sales = hans_rosling_year_and_rbics.loc[:, 'sales_total']
    mktval = hans_rosling_year_and_rbics.loc[:, 'mkt_val']
    rbics = hans_rosling_year_and_rbics.loc[:, 'rbics_econ']
    rbics_color = hans_rosling_year_and_rbics.loc[:, 'rbics_sect_color']
    ticker = hans_rosling_year_and_rbics.loc[:, 'Symbol']
    
    # Store Symbol and coordinates for select Companies into a dictionary
    # Dictionary is used for better error handling when Company does not exist in the chart
    my_dict = {}

    for symbol in ['FB', 'AMZN', 'AAPL', 'NFLX', 'GOOG', 'MSFT', 'BRK.B', 'WMT', 'XOM',
                   'DIS', 'TWX', 'FOX', 'PG', 'BA', 'GE', 'JNJ', 'UNH',
                   'HD', 'NKE', 'GM', 'DUK', 'JPM', 'V', 'GS', 'KO', 'MO',
                   'CVX', 'T', 'VZ', 'ADP']:
        symbol_filter = hans_rosling_year_and_rbics.loc[:, 'Symbol'] == symbol
        label = np.array((hans_rosling_year_and_rbics.loc[symbol_filter, ['esg_combined', 'sales_total']]))
        if label.size >1:
            my_dict.update({symbol: (label[0][0], label[0][1])})
    
    
    # Scatter plot
    plt.scatter(x = esg_score, y = sales, s = mktval/100 , edgecolors='black', c = rbics_color, alpha=.75)

    
    # customizations
    plt.yscale('log')
    plt.xlabel('ESG Score')
    plt.ylabel('Revenue')
    plt.xlim(0,25)
    plt.ylim(500, 700000)
    plt.title(year)
    plt.yticks([1000,10000,100000], ['1m','10m','100m'])

    
    # Adding Labels for Symbol, ESG score, and Sales Total
    for key, value in my_dict.items():
        plt.text(value[0], value[1], key)
    
    
    # Add grid() 
    plt.grid(True)

    
    # return and display the plot
    return plt.show()

# %%
# Define a function that filters the dataframe by date    
date_filter = hans_rosling.loc[:, 'Date'] == '12/29/2017'
hans_rosling_year = hans_rosling.loc[date_filter, :]

# filter by rbics_sect
rbics_filter = hans_rosling_year.loc[:, 'rbics_econ'] == 'Business Services'
hans_rosling_year_and_rbics = hans_rosling_year.loc[rbics_filter, :]

# %%
(hans_rosling_year_and_rbics.sort_values('mkt_val', ascending=False))
# Out:
#      Symbol                                  Name        Date       mkt_val  \
# 5071    ADP       Automatic Data Processing, Inc.  12/29/2017  51880.013000
# 5309    MMC      Marsh & McLennan Companies, Inc.  12/29/2017  41404.029390
# 5493     WM                Waste Management, Inc.  12/29/2017  37395.421330
# 5332    MCO                   Moody's Corporation  12/29/2017  28189.098680
# 5369   PAYX                         Paychex, Inc.  12/29/2017  24453.346250
# 5409    RSG               Republic Services, Inc.  12/29/2017  22426.237000
# 5362    OMC                     Omnicom Group Inc  12/29/2017  16758.183000
# 5124   CTAS                    Cintas Corporation  12/29/2017  16591.231480
# 5482   VRSK                  Verisk Analytics Inc  12/29/2017  15828.377280
# 5188    EFX                          Equifax Inc.  12/29/2017  14162.192000
# 5348   NLSN                  Nielsen Holdings Plc  12/29/2017  12956.397130
# 5267    IPG  Interpublic Group of Companies, Inc.  12/29/2017   7725.312000
# 5411    RHI        Robert Half International Inc.  12/29/2017   6901.481377
# 5233    HRB                       H&R Block, Inc.  12/29/2017   5481.774077
# 5147   CSRA                            CSRA, Inc.  12/29/2017   4901.703840
#
#       rbics_econn         rbics_econ  rbics_sectn         rbics_sect  \
# 5071         10.0  Business Services       1010.0  Business Services
# 5309         10.0  Business Services       1010.0  Business Services
# 5493         10.0  Business Services       1010.0  Business Services
# 5332         10.0  Business Services       1010.0  Business Services
# 5369         10.0  Business Services       1010.0  Business Services
# 5409         10.0  Business Services       1010.0  Business Services
# 5362         10.0  Business Services       1010.0  Business Services
# 5124         10.0  Business Services       1010.0  Business Services
# 5482         10.0  Business Services       1010.0  Business Services
# 5188         10.0  Business Services       1010.0  Business Services
# 5348         10.0  Business Services       1010.0  Business Services
# 5267         10.0  Business Services       1010.0  Business Services
# 5411         10.0  Business Services       1010.0  Business Services
# 5233         10.0  Business Services       1010.0  Business Services
# 5147         10.0  Business Services       1010.0  Business Services
#
#       rbics_subsectn                    rbics_subsect      ...       \
# 5071        101015.0      Other Professional Services      ...
# 5309        101015.0      Other Professional Services      ...
# 5493        101025.0        Waste Management Services      ...
# 5332        101015.0      Other Professional Services      ...
# 5369        101015.0      Other Professional Services      ...
# 5409        101025.0        Waste Management Services      ...
# 5362        101010.0  Marketing and Printing Services      ...
# 5124        101020.0        Business Support Services      ...
# 5482        101015.0      Other Professional Services      ...
# 5188        101015.0      Other Professional Services      ...
# 5348        101015.0      Other Professional Services      ...
# 5267        101010.0  Marketing and Printing Services      ...
# 5411        101015.0      Other Professional Services      ...
# 5233        101015.0      Other Professional Services      ...
# 5147        101015.0      Other Professional Services      ...
#
#       rbics_subindn                                       rbics_subind  \
# 5071   1.010150e+11  Other Human Resources Consulting and PEO Services
# 5309   1.010150e+11           Consulting and Business Process Services
# 5493   1.010250e+11                           General Waste Collection
# 5332   1.010150e+11                     Credit and Information Bureaus
# 5369   1.010150e+11                                   Payroll Services
# 5409   1.010250e+11                           General Waste Collection
# 5362   1.010100e+11    Marketing and Advertising Agencies and Networks
# 5124   1.010200e+11                  Linen and Uniform Supply Services
# 5482   1.010150e+11      Insurance Claims and Risk Management Services
# 5188   1.010150e+11                     Credit and Information Bureaus
# 5348   1.010150e+11                           Market Research Services
# 5267   1.010100e+11    Marketing and Advertising Agencies and Networks
# 5411   1.010150e+11                                  Staffing Services
# 5233   1.010150e+11                           Tax Preparation Services
# 5147   1.010150e+11                             Government IT Services
#
#       msci_esg_env msci_esg_gov  msci_esg_social sales_total   sales_ps  \
# 5071          10.0          5.8              3.9   12789.800  27.492338
# 5309          10.0          4.2              6.0   14039.000  27.050096
# 5493           4.9          4.1              4.5   14485.000  32.778909
# 5332           8.7          5.4              0.9    4204.100  21.648301
# 5369           6.7          3.3              4.1    3237.700   8.690844
# 5409           1.7          6.7              3.4   10044.500  29.630864
# 5362          10.0          3.7              5.0   15273.600  65.299701
# 5124           7.2          4.0              3.9    6003.598  49.389802
# 5482           8.0          3.2              4.3    2145.200  12.716903
# 5188           6.0          6.5              2.6    3362.200  27.672428
# 5348          10.0          6.5              3.6    6572.000  18.354854
# 5267           8.0          4.8              3.7    8192.300  19.839919
# 5411           8.0          5.6              5.0    5266.789  42.170748
# 5233           5.9          7.4              2.6    3058.453  14.182087
# 5147           3.3          6.8              2.6    5064.000  30.305880
#
#       sales_growth  rbics_sect_color  esg_combined
# 5071      6.130612              pink          19.7
# 5309      6.364118              pink          20.2
# 5493      6.436917              pink          13.5
# 5332     16.644470              pink          15.0
# 5369      5.689756              pink          14.1
# 5409      6.996389              pink          11.8
# 5362     -0.929499              pink          18.7
# 5124     19.469475              pink          15.1
# 5482      7.519229              pink          15.5
# 5188      6.274299              pink          15.1
# 5348      4.168648              pink          20.1
# 5267      4.405730              pink          16.5
# 5411      0.312167              pink          18.6
# 5233      0.987804              pink          15.9
# 5147      0.591152              pink          12.7
#
# [15 rows x 24 columns]

# %%
hans_rosling_date_and_rbics('12/29/2017', 'Business Services')

# %%
hans_rosling_date_and_rbics('12/30/2016', 'Business Services')

# %%
hans_rosling_date_and_rbics('12/31/2015', 'Business Services')

# %%
hans_rosling_date_and_rbics('12/31/2014', 'Business Services')

# %%
hans_rosling_date_and_rbics('12/31/2013', 'Business Services')

# %%
hans_rosling_date_and_rbics('12/31/2012', 'Business Services')

# %%
hans_rosling_date_and_rbics('12/30/2011', 'Business Services')

# %%
hans_rosling_date_and_rbics('12/31/2010', 'Business Services')

# %%
hans_rosling_date_and_rbics('12/31/2009', 'Business Services')

# %%
hans_rosling_date_and_rbics('12/31/2008', 'Business Services')

# %%
hans_rosling_date_and_rbics('12/31/2007', 'Business Services')
