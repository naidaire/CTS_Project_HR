# %% [markdown]
# # Data Visualization Project
#
# Open:FactSet Insights and Analysis team.
#
# The team mission is to educate, inspire, and empower FactSetters and clients to utilize Open:FactSet Data and Solutions.
#
# As part of the team you will be tasked with creating and communicating compelling stories for Marketplace content.  Secondarily, the team collective will need to develop best practices and methods for disseminating knowledge both internally and externally.  For the interview please prepare a 20-30 minute presentation covering:
#
# 1. For an audience of CTS Sales, create a presentation showcasing a FactSet content set using Python, R, or SQL.  The goal is to educate on potential applications, how a given technology is applied and how to pitch this to their client base.
#     - Python, Jupyter Notebook, Ondemand?,
#     - Unique Datasets - RBICs + ESG Data
#     - Exploratory Data Analysis
#     - Hans Rosling Chart

# %%
from pathlib import Path

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

#Increase default figure and font sizes for easier viewing.
plt.rcParams['figure.figsize'] = (16, 9)
plt.rcParams['font.size'] = 14

plt.style.use('fivethirtyeight')

# %%
data  = Path('.', 'assets', 'rbics_esg_data_qtr.csv')
hans_rosling = pd.read_csv(data, na_values= '@NA')

# %%
hans_rosling = hans_rosling.dropna()

# %%
hans_rosling.columns = ['Symbol', 'Name', 'Date', 'mkt_val', 'rbics_econn', 'rbics_econ',
       'rbics_sectn', 'rbics_sect', 'rbics_subsectn', 'rbics_subsect',
       'rbics_indgrpn', 'rbics_indgrp', 'rbics_indn', 'rbics_ind',
       'rbics_subindn', 'rbics_subind', 'msci_esg_env', 'msci_esg_gov',
       'msci_esg_social', 'sales_total', 'sales_ps', 'sales_growth',
       'msci_esg_score', 'msci_esg_rating']

# %%
# RBICS Econonmic Focus Color Map 
# source:  https://matplotlib.org/2.0.2/examples/color/named_colors.html

econ_color_dict = {
    'Non-Energy Materials': 'black', 
    'Industrials': 'white', 
    'Healthcare': 'gray', 
    'Technology': 'red',
    'Consumer Cyclicals': 'orange', 
    'Utilities': 'yellow', 
    'Finance': 'green',
    'Consumer Non-Cyclicals': 'blue', 
    'Energy': 'indigo', 
    'Telecommunications': 'violet',
    'Business Services': 'pink', 
    'Consumer Services': 'chocolate',
    'Other': 'black'
    
}

# %%
# RBICS Sector Focus Color Map
# source:  https://matplotlib.org/2.0.2/examples/color/named_colors.html

sect_color_dict = {
    'Manufactured Products': 'black', 
    'Industrial Manufacturing': 'white',
    'Healthcare Equipment': 'lightgray', 
    'Biopharmaceuticals': 'gray',
    'Software and Consulting': 'red', 
    'Miscellaneous Retail': 'darkorange',
    'Electronic Components and Manufacturing': 'darkred', 
    'Utilities': 'yellow',
    'Healthcare Services': 'silver', 
    'Investment Services': 'lawngreen', 
    'Insurance': 'green',
    'Chemical, Plastic and Rubber Materials': 'k', 
    'Real Estate': 'seagreen',
    'Mining and Mineral Products': 'dimgray', 
    'Specialty Finance and Services': 'darkolivegreen',
    'Food and Tobacco Production': 'blue', 
    'Food and Staples Retail': 'dodgerblue',
    'Industrial Services': 'whitesmoke', 
    'Upstream Energy': 'indigo',
    'Downstream and Midstream Energy': 'blueviolet', 
    'Hardware': 'firebrick',
    'Consumer Vehicles and Parts': 'peachpuff', 
    'Telecommunications': 'violet',
    'Business Services': 'pink', 
    'Banking': 'forestgreen', 
    'Consumer Retail': 'orange',
    'Hospitality Services': 'sienna', 
    'Media and Publishing Services': 'saddlebrown',
    'Household Products': 'navy', 
    'Household Services': 'royalblue',
    'Consumer Goods': 'sandybrown',
    'General or Multi-Industry Revenue': 'black'
    
}

# %%
# Sum ESG Scores for Environment + Social + Government
hans_rosling.loc[:, 'rbics_sect_color'] = hans_rosling.loc[:, 'rbics_sect'].map(sect_color_dict)
#hans_rosling.loc[:, 'esg_combined'] = hans_rosling.loc[:, ['msci_esg_env','msci_esg_social', 'msci_esg_gov']].sum(axis=1)

# %%
def hans_rosling_date_and_rbics(year, econ):
    #Define a function that creates a scatter plot based on x = esg_score, y = sales_total, size = mkt_val, color = rbics_sector
    #Filter by date and rbics econ
    
    # Define a function that filters the dataframe by date    
    date_filter = hans_rosling.loc[:, 'Date'] == year
    hans_rosling_year = hans_rosling.loc[date_filter, :]
    
    # filter by rbics_sect
    rbics_filter = hans_rosling_year.loc[:, 'rbics_econ'] == econ
    hans_rosling_year_and_rbics = hans_rosling_year.loc[rbics_filter, :]
    
    
    #store values into array variables for scatter plot
    esg_score = hans_rosling_year_and_rbics.loc[:, 'msci_esg_score']
    sales = hans_rosling_year_and_rbics.loc[:, 'sales_total']
    mktval = hans_rosling_year_and_rbics.loc[:, 'mkt_val']
    rbics = hans_rosling_year_and_rbics.loc[:, 'rbics_econ']
    rbics_color = hans_rosling_year_and_rbics.loc[:, 'rbics_sect_color']
    ticker = hans_rosling_year_and_rbics.loc[:, 'Symbol']
    
    # Store Symbol and coordinates for select Companies into a dictionary
    # Dictionary is used for better error handling when Company does not exist in the chart
    my_dict = {}

    for symbol in ['FB', 'AMZN', 'AAPL', 'NFLX', 'GOOG', 'BRK.B', 'WMT', 'XOM',
                   'MSFT','DIS', 'TWX', 'FOX', 'PG', 'BA', 'GE', 'JNJ', 'UNH',
                   'HD', 'NKE', 'GM', 'DUK', 'JPM', 'V', 'GS', 'KO', 'MO',
                   'CVX', 'T', 'VZ', 'ADP']:
        symbol_filter = hans_rosling_year_and_rbics.loc[:, 'Symbol'] == symbol
        label = np.array((hans_rosling_year_and_rbics.loc[symbol_filter, ['msci_esg_score', 'sales_total']]))
        if label.size >1:
            my_dict.update({symbol: (label[0][0], label[0][1])})
    
    
    # Scatter plot
    plt.scatter(x = esg_score, y = sales, s = mktval/100 , edgecolors='black', c = rbics_color, alpha=.75)

    
    # customizations
    plt.yscale('log')
    plt.xlabel('ESG Score')
    plt.ylabel('Revenue')
    plt.xlim(-1,11)
    plt.ylim(500, 700000)
    plt.title(year)
    plt.yticks([1000,10000,100000], ['1b','10b','100b'])

    
    # Adding Labels for Symbol, ESG score, and Sales Total
    for key, value in my_dict.items():
        plt.text(value[0], value[1], key)
    
    
    # Add grid() 
    plt.grid(True)

    
    # return and display the plot
    return plt.show()

# %%
# Define a function that filters the dataframe by date    
date_filter = hans_rosling.loc[:, 'Date'] == '12/29/2017'
hans_rosling_year = hans_rosling.loc[date_filter, :]

# filter by rbics_sect
# 14352    MAS                     Masco Corporation  12/29/2017   13638.976000
# 14355    MKC     McCormick & Company, Incorporated  12/29/2017   13350.210000
# 14161    CHD             Church & Dwight Co., Inc.  12/29/2017   12423.591980
# 14258   FBHS  Fortune Brands Home & Security, Inc.  12/29/2017   10396.501190
# 14337    LUK         Leucadia National Corporation  12/29/2017    9436.454237
# 14328    KSS                    Kohl's Corporation  12/29/2017    9110.640000
# 14393    JWN                       Nordstrom, Inc.  12/29/2017    7893.508000
# 14346      M                            Macy's Inc  12/29/2017    7672.027037
#
#        rbics_econn              rbics_econ  rbics_sectn  \
# 14082         50.0  Consumer Non-Cyclicals       5010.0
# 14532         50.0  Consumer Non-Cyclicals       5010.0
# 14429         50.0  Consumer Non-Cyclicals       5020.0
# 14173         50.0  Consumer Non-Cyclicals       5015.0
# 14414         50.0  Consumer Non-Cyclicals       5015.0
# 14419         50.0  Consumer Non-Cyclicals       5015.0
# 14081         50.0  Consumer Non-Cyclicals       5015.0
# 14329         50.0  Consumer Non-Cyclicals       5015.0
# 14185         50.0  Consumer Non-Cyclicals       5010.0
# 14191         50.0  Consumer Non-Cyclicals       5010.0
# 14531         50.0  Consumer Non-Cyclicals       5010.0
# 14175         50.0  Consumer Non-Cyclicals       5020.0
# 14370         50.0  Consumer Non-Cyclicals       5015.0
# 14495         50.0  Consumer Non-Cyclicals       5010.0
# 14233         50.0  Consumer Non-Cyclicals       5020.0
# 14182         50.0  Consumer Non-Cyclicals       5015.0
# 14324         50.0  Consumer Non-Cyclicals       5020.0
# 14218         50.0  Consumer Non-Cyclicals       5010.0
# 14372         50.0  Consumer Non-Cyclicals       5015.0
# 14487         50.0  Consumer Non-Cyclicals       5010.0
# 14266         50.0  Consumer Non-Cyclicals       5015.0
# 14484         50.0  Consumer Non-Cyclicals       5010.0
# 14456         50.0  Consumer Non-Cyclicals       5010.0
# 14504         50.0  Consumer Non-Cyclicals       5015.0
# 14134         50.0  Consumer Non-Cyclicals       5015.0
# 14206         50.0  Consumer Non-Cyclicals       5010.0
# 14205         50.0  Consumer Non-Cyclicals       5010.0
# 14330         50.0  Consumer Non-Cyclicals       5010.0
# 14322         50.0  Consumer Non-Cyclicals       5015.0
# 14285         50.0  Consumer Non-Cyclicals       5015.0
# 14106         50.0  Consumer Non-Cyclicals       5015.0
# 14170         50.0  Consumer Non-Cyclicals       5020.0
# 14292         50.0  Consumer Non-Cyclicals       5015.0
# 14369         50.0  Consumer Non-Cyclicals       5015.0
# 14210         50.0  Consumer Non-Cyclicals       5015.0
# 14178         50.0  Consumer Non-Cyclicals       5015.0
# 14383         50.0  Consumer Non-Cyclicals       5020.0
# 14186         50.0  Consumer Non-Cyclicals       5020.0
# 14140         50.0  Consumer Non-Cyclicals       5015.0
# 14314         50.0  Consumer Non-Cyclicals       5015.0
# 14507         50.0  Consumer Non-Cyclicals       5010.0
# 14352         50.0  Consumer Non-Cyclicals       5020.0
# 14355         50.0  Consumer Non-Cyclicals       5015.0
# 14161         50.0  Consumer Non-Cyclicals       5020.0
# 14258         50.0  Consumer Non-Cyclicals       5020.0
# 14134         Food and Beverage Production        ...
# 14206           General Merchandise Retail        ...
# 14205           General Merchandise Retail        ...
# 14330             Food and Beverage Retail        ...
# 14322         Food and Beverage Production        ...
# 14285         Food and Beverage Production        ...
# 14106                          Agriculture        ...
# 14170  Personal Care and Cleaning Products        ...
# 14292         Food and Beverage Production        ...
# 14369         Food and Beverage Production        ...
# 14210         Food and Beverage Production        ...
# 14178         Food and Beverage Production        ...
# 14383                   Household Products        ...
# 14186  Personal Care and Cleaning Products        ...
# 14140         Food and Beverage Production        ...
# 14314         Food and Beverage Production        ...
# 14507      Health and Personal Care Retail        ...
# 14352                   Household Products        ...
# 14355         Food and Beverage Production        ...
# 14161  Personal Care and Cleaning Products        ...
# 14258                   Household Products        ...
# 14337         Food and Beverage Production        ...
# 14328           General Merchandise Retail        ...
# 14393           General Merchandise Retail        ...
# 14346           General Merchandise Retail        ...
#
#                                             rbics_subind msci_esg_env  \
# 14082                      General Merchandise Retailers          1.1
# 14532              Warehouse Club Stores and Superstores          7.7
# 14429  General Personal Care and Cleaning Products Ma...          7.4
# 14173   Juices, Soft Drinks and Energy Drinks Production          7.6
# 14414   Juices, Soft Drinks and Energy Drinks Production          8.1
# 14419                            Cigarette Manufacturing          4.2
# 14081                            Cigarette Manufacturing          3.4
# 14329          General Food Manufacturing and Processing          4.4
# 14185              Warehouse Club Stores and Superstores          4.0
# 14191                         Pharmacies and Drug Stores          4.8
# 14531                         Pharmacies and Drug Stores          7.9
# 14175  General Personal Care and Cleaning Products Ma...          8.6
# 14370                       Sweets and Snacks Production          6.0
# 14495                            Off-Price Retail Stores          3.7
# 14233  General Personal Care and Cleaning Products Ma...          8.9
# 14182                                          Breweries          3.5
# 14324                   Absorbent Products Manufacturing          7.2
# 14218                      General Merchandise Retailers         10.0
# 14372   Juices, Soft Drinks and Energy Drinks Production          0.5
# 14487              Warehouse Club Stores and Superstores          6.1
# 14266          General Food Manufacturing and Processing          6.5
# 14484                        General Line Grocery Retail          2.8
# 14456                            Off-Price Retail Stores          4.1
# 14504              Beef, Pork and Other Meats Production          2.7
# 14134                                       Distilleries          3.6
# 14206                            General Discount Stores          2.9
# 14205                            General Discount Stores          2.5
# 14330                         United States Supermarkets          5.4
# 14322                       Sweets and Snacks Production          6.7
# 14285                        Confectionery Manufacturing          4.2
# 14106                                    Crop Processing          5.8
# 14170                        Household Cleaning Products          7.1
# 14292                        Meat and Seafood Production          3.0
# 14369                                          Breweries          5.0
# 14210   Juices, Soft Drinks and Energy Drinks Production          4.2
# 14178          General Food Manufacturing and Processing          4.0
# 14383              Diversified Household Products Makers          9.8
# 14186  General Personal Care and Cleaning Products Ma...          3.6
# 14140      Other Soups, Sauces and Condiments Production          5.6
# 14314          General Food Manufacturing and Processing          4.2
# 14507              Other Health and Personal Care Stores          0.7
# 14352              Diversified Household Products Makers          6.8
# 14355                  Spices and Extracts Manufacturing          3.2
# 14161  General Personal Care and Cleaning Products Ma...          5.4
# 14258              Diversified Household Products Makers          6.0
# 14337              Beef, Pork and Other Meats Production          4.0
# 14429             8.2               AA              navy
# 14173             6.9                A              blue
# 14414             8.3               AA              blue
# 14419             4.1               BB              blue
# 14081             3.5               BB              blue
# 14329             5.3              BBB              blue
# 14185             1.6                B        dodgerblue
# 14191             2.8                B        dodgerblue
# 14531             3.4               BB        dodgerblue
# 14175             7.8               AA              navy
# 14370             5.8                A              blue
# 14495             3.1               BB        dodgerblue
# 14233             5.6              BBB              navy
# 14182             2.9               BB              blue
# 14324             6.9                A              navy
# 14218             3.2               BB        dodgerblue
# 14372             0.0              CCC              blue
# 14487             5.6              BBB        dodgerblue
# 14266             8.3               AA              blue
# 14484             3.4               BB        dodgerblue
# 14456             3.8               BB        dodgerblue
# 14504             2.5                B              blue
# 14134             3.3               BB              blue
# 14206             1.8                B        dodgerblue
# 14205             1.8                B        dodgerblue
# 14330             4.4              BBB        dodgerblue
# 14322             9.4              AAA              blue
# 14285             4.7              BBB              blue
# 14106             5.8                A              blue
# 14170             8.0               AA              navy
# 14292             6.4                A              blue
# 14369             6.9                A              blue
# 14210             4.5              BBB              blue
# 14178             5.3              BBB              blue
# 14383             7.0                A              navy
# 14186             1.8                B              navy
# 14140             8.3               AA              blue
# 14314             5.0              BBB              blue
# 14507             3.1               BB        dodgerblue
# 14352             6.4                A              navy
# 14355             6.7                A              blue
# 14161             3.6               BB              navy
# 14258             5.6              BBB              navy
# 14337             1.6                B              blue
# 14328             4.1               BB        dodgerblue
# 14393             6.7                A        dodgerblue
# 14346             4.1               BB        dodgerblue
#
# [49 rows x 25 columns]

# %%
hans_rosling.Date.unique()
# Out:
# array(['12/31/2010', ' 3/31/2011', ' 6/30/2011', ' 9/30/2011',
#        '12/30/2011', ' 3/30/2012', ' 6/29/2012', ' 9/28/2012',
#        '12/31/2012', ' 3/28/2013', ' 6/28/2013', ' 9/30/2013',
#        '12/31/2013', ' 3/31/2014', ' 6/30/2014', ' 9/30/2014',
#        '12/31/2014', ' 3/31/2015', ' 6/30/2015', ' 9/30/2015',
#        '12/31/2015', ' 3/31/2016', ' 6/30/2016', ' 9/30/2016',
#        '12/30/2016', ' 3/31/2017', ' 6/30/2017', ' 9/29/2017', '12/29/2017'], dtype=object)

# %%
#Splitting dates into separate variables so the Notebook doesn't crash

dateA = ['12/31/2010', ' 3/31/2011', ' 6/30/2011', ' 9/30/2011',
       '12/30/2011', ' 3/30/2012', ' 6/29/2012', ' 9/28/2012',
       '12/31/2012', ' 3/28/2013'
        ]

dateB = [' 6/28/2013', ' 9/30/2013','12/31/2013', ' 3/31/2014', 
         ' 6/30/2014', ' 9/30/2014', '12/31/2014', ' 3/31/2015', 
         ' 6/30/2015', ' 9/30/2015'
        ]

dateC = ['12/31/2015', ' 3/31/2016', ' 6/30/2016', ' 9/30/2016',
         '12/30/2016', ' 3/31/2017', ' 6/30/2017', ' 9/29/2017', 
         '12/29/2017']

# %%
for date in dateA:
    hans_rosling_date_and_rbics(date, 'Finance')

# %%
for date in dateB:
    hans_rosling_date_and_rbics(date, 'Finance')

# %%
for date in dateC:
    hans_rosling_date_and_rbics(date, 'Finance')
