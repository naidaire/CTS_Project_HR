# %% [markdown]
# # Data Visualization Project
#
# Open:FactSet Insights and Analysis team.
#
# The team mission is to educate, inspire, and empower FactSetters and clients to utilize Open:FactSet Data and Solutions.
#
# As part of the team you will be tasked with creating and communicating compelling stories for Marketplace content.  Secondarily, the team collective will need to develop best practices and methods for disseminating knowledge both internally and externally.  For the interview please prepare a 20-30 minute presentation covering:
#
# 1. For an audience of CTS Sales, create a presentation showcasing a FactSet content set using Python, R, or SQL.  The goal is to educate on potential applications, how a given technology is applied and how to pitch this to their client base.
#     - Python, Jupyter Notebook, Ondemand?,
#     - Unique Datasets - RBICs + ESG Data
#     - Exploratory Data Analysis
#     - Hans Rosling Chart

# %%
from pathlib import Path

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

#Increase default figure and font sizes for easier viewing.
plt.rcParams['figure.figsize'] = (16, 9)
plt.rcParams['font.size'] = 14

plt.style.use('fivethirtyeight')

# %%
data  = Path('.', 'assets', 'rbics_esg_data.csv')
hans_rosling = pd.read_csv(data, na_values= '-')

# %%
hans_rosling = hans_rosling.dropna()

# %%
# RBICS Econonmic Focus Color Map 
# source:  https://matplotlib.org/2.0.2/examples/color/named_colors.html

econ_color_dict = {
    'Non-Energy Materials': 'black', 
    'Industrials': 'white', 
    'Healthcare': 'gray', 
    'Technology': 'red',
    'Consumer Cyclicals': 'orange', 
    'Utilities': 'yellow', 
    'Finance': 'green',
    'Consumer Non-Cyclicals': 'blue', 
    'Energy': 'indigo', 
    'Telecommunications': 'violet',
    'Business Services': 'pink', 
    'Consumer Services': 'chocolate'
    
}

# %%
# RBICS Sector Focus Color Map
# source:  https://matplotlib.org/2.0.2/examples/color/named_colors.html

sect_color_dict = {
    'Manufactured Products': 'black', 
    'Industrial Manufacturing': 'white',
    'Healthcare Equipment': 'lightgray', 
    'Biopharmaceuticals': 'gray',
    'Software and Consulting': 'red', 
    'Miscellaneous Retail': 'darkorange',
    'Electronic Components and Manufacturing': 'darkred', 
    'Utilities': 'yellow',
    'Healthcare Services': 'silver', 
    'Investment Services': 'lawngreen', 
    'Insurance': 'green',
    'Chemical, Plastic and Rubber Materials': 'k', 
    'Real Estate': 'seagreen',
    'Mining and Mineral Products': 'dimgray', 
    'Specialty Finance and Services': 'darkolivegreen',
    'Food and Tobacco Production': 'blue', 
    'Food and Staples Retail': 'dodgerblue',
    'Industrial Services': 'whitesmoke', 
    'Upstream Energy': 'indigo',
    'Downstream and Midstream Energy': 'blueviolet', 
    'Hardware': 'firebrick',
    'Consumer Vehicles and Parts': 'peachpuff', 
    'Telecommunications': 'violet',
    'Business Services': 'pink', 
    'Banking': 'forestgreen', 
    'Consumer Retail': 'orange',
    'Hospitality Services': 'sienna', 
    'Media and Publishing Services': 'saddlebrown',
    'Household Products': 'navy', 
    'Household Services': 'royalblue',
    'Consumer Goods': 'sandybrown'
    
}

# %%
# Sum ESG Scores for Environment + Social + Government
hans_rosling.loc[:, 'rbics_sect_color'] = hans_rosling.loc[:, 'rbics_sect'].map(sect_color_dict)
hans_rosling.loc[:, 'esg_combined'] = hans_rosling.loc[:, ['msci_esg_env','msci_esg_social', 'msci_esg_gov']].sum(axis=1)

# %%
def hans_rosling_date_and_rbics(year, econ):
    #Define a function that creates a scatter plot based on x = esg_score, y = sales_total, size = mkt_val, color = rbics_sector
    #Filter by date and rbics econ
    
    # Define a function that filters the dataframe by date    
    date_filter = hans_rosling.loc[:, 'Date'] == year
    hans_rosling_year = hans_rosling.loc[date_filter, :]
    
    # filter by rbics_sect
    rbics_filter = hans_rosling_year.loc[:, 'rbics_econ'] == econ
    hans_rosling_year_and_rbics = hans_rosling_year.loc[rbics_filter, :]
    
    
    #store values into array variables for scatter plot
    esg_score = hans_rosling_year_and_rbics.loc[:, 'esg_combined']
    sales = hans_rosling_year_and_rbics.loc[:, 'sales_total']
    mktval = hans_rosling_year_and_rbics.loc[:, 'mkt_val']
    rbics = hans_rosling_year_and_rbics.loc[:, 'rbics_econ']
    rbics_color = hans_rosling_year_and_rbics.loc[:, 'rbics_sect_color']
    ticker = hans_rosling_year_and_rbics.loc[:, 'Symbol']
    
    # Store Symbol and coordinates for select Companies into a dictionary
    # Dictionary is used for better error handling when Company does not exist in the chart
    my_dict = {}

    for symbol in ['FB', 'AMZN', 'AAPL', 'NFLX', 'GOOG', 'BRK.B', 'WMT', 'XOM',
                   'DIS', 'TWX', 'FOX', 'PG', 'BA', 'GE', 'JNJ', 'UNH',
                   'HD', 'NKE', 'GM', 'DUK', 'JPM', 'V', 'GS', 'KO', 'MO',
                   'CVX', 'T', 'VZ', 'ADP']:
        symbol_filter = hans_rosling_year_and_rbics.loc[:, 'Symbol'] == symbol
        label = np.array((hans_rosling_year_and_rbics.loc[symbol_filter, ['esg_combined', 'sales_total']]))
        if label.size >1:
            my_dict.update({symbol: (label[0][0], label[0][1])})
    
    
    # Scatter plot
    plt.scatter(x = esg_score, y = sales, s = mktval/100 , edgecolors='black', c = rbics_color, alpha=.75)

    
    # customizations
    plt.yscale('log')
    plt.xlabel('ESG Score')
    plt.ylabel('Revenue')
    plt.xlim(0,25)
    plt.ylim(500, 700000)
    plt.title(year)
    plt.yticks([1000,10000,100000], ['1m','10m','100m'])

    
    # Adding Labels for Symbol, ESG score, and Sales Total
    for key, value in my_dict.items():
        plt.text(value[0], value[1], key)
    
    
    # Add grid() 
    plt.grid(True)

    
    # return and display the plot
    return plt.show()

# %%
# Define a function that filters the dataframe by date    
date_filter = hans_rosling.loc[:, 'Date'] == '12/29/2017'
hans_rosling_year = hans_rosling.loc[date_filter, :]

# filter by rbics_sect
rbics_filter = hans_rosling_year.loc[:, 'rbics_econ'] == 'Technology'
hans_rosling_year_and_rbics = hans_rosling_year.loc[rbics_filter, :]

# %%
(hans_rosling_year_and_rbics.sort_values('mkt_val', ascending=False))
# Out:
#      Symbol                                               Name        Date  \
# 5062   AAPL                                         Apple Inc.  12/29/2017
# 5038  GOOGL                              Alphabet Inc. Class A  12/29/2017
# 5039   GOOG                              Alphabet Inc. Class C  12/29/2017
# 5325   MSFT                              Microsoft Corporation  12/29/2017
# 5202     FB                             Facebook, Inc. Class A  12/29/2017
# 5262   INTC                                  Intel Corporation  12/29/2017
# 5418                  Software and Consulting        552015.0
# 5063  Electronic Components and Manufacturing        551030.0
# 5016                  Software and Consulting        552015.0
# 5324  Electronic Components and Manufacturing        551020.0
# 5417                  Software and Consulting        552010.0
# 5133                  Software and Consulting        552020.0
# 5268                  Software and Consulting        552015.0
# 5253                                 Hardware        551520.0
# 5447  Electronic Components and Manufacturing        551010.0
# 5055  Electronic Components and Manufacturing        551020.0
# 5181                  Software and Consulting        552015.0
# 5293  Electronic Components and Manufacturing        551030.0
# 5173                  Software and Consulting        552020.0
# 5053  Electronic Components and Manufacturing        551010.0
# 5498                                 Hardware        551520.0
# 5070                  Software and Consulting        552015.0
# 5246                  Software and Consulting        552020.0
# 5405                  Software and Consulting        552015.0
# 5323  Electronic Components and Manufacturing        551020.0
# 5440                  Software and Consulting        552015.0
# 5429  Electronic Components and Manufacturing        551020.0
# 5509  Electronic Components and Manufacturing        551020.0
# 5286  Electronic Components and Manufacturing        551030.0
# 5340                                 Hardware        551520.0
# 5335                                 Hardware        551515.0
# 5096                  Software and Consulting        552015.0
# 5442                  Software and Consulting        552015.0
# 5128                  Software and Consulting        552015.0
# 5057                  Software and Consulting        552015.0
# 5423                                 Hardware        551520.0
# 5098                  Software and Consulting        552015.0
# 5221                                 Hardware        551515.0
# 5222                  Software and Consulting        552010.0
# 5481                  Software and Consulting        552010.0
# 5027                  Software and Consulting        552010.0
# 5279                                 Hardware        551515.0
# 5020  Electronic Components and Manufacturing        551020.0
# 5396  Electronic Components and Manufacturing        551010.0
# 5201                                 Hardware        551515.0
# 5508                                 Hardware        551520.0
#
#                              rbics_subsect      ...       rbics_subindn  \
# 5062              Communications Equipment      ...        5.515150e+11
# 5038            Internet and Data Services      ...        5.520100e+11
# 5039            Internet and Data Services      ...        5.520100e+11
# 5325                              Software      ...        5.520150e+11
# 5202            Internet and Data Services      ...        5.520100e+11
# 5262           Semiconductor Manufacturing      ...        5.510200e+11
# 5364                              Software      ...        5.520150e+11
# 5125              Communications Equipment      ...        5.515150e+11
# 5264        Technology Consulting Services      ...        5.520200e+11
# 5359           Semiconductor Manufacturing      ...        5.510200e+11
# 5449           Semiconductor Manufacturing      ...        5.510200e+11
# 5397           Semiconductor Manufacturing      ...        5.510200e+11
# 5015        Technology Consulting Services      ...        5.520200e+11
# 5018                              Software      ...        5.520150e+11
# 5341            Internet and Data Services      ...        5.520100e+11
# 5418                              Software      ...        5.520150e+11
# 5063  Semiconductor Equipment and Services      ...        5.510300e+11
# 5016                              Software      ...        5.520150e+11
# 5324           Semiconductor Manufacturing      ...        5.510200e+11
# 5417            Internet and Data Services      ...        5.520100e+11
# 5133        Technology Consulting Services      ...        5.520200e+11
# 5268                              Software      ...        5.520150e+11
# 5253         Computer Hardware and Storage      ...        5.515200e+11
# 5447                 Electronic Components      ...        5.510100e+11
# 5055           Semiconductor Manufacturing      ...        5.510200e+11
# 5181                              Software      ...        5.520150e+11
# 5293  Semiconductor Equipment and Services      ...        5.510300e+11
# 5173        Technology Consulting Services      ...        5.520200e+11
# 5053                 Electronic Components      ...        5.510100e+11
# 5498         Computer Hardware and Storage      ...        5.515200e+11
# 5070                              Software      ...        5.520150e+11
# 5246        Technology Consulting Services      ...        5.520200e+11
# 5405                              Software      ...        5.520150e+11
# 5323           Semiconductor Manufacturing      ...        5.510200e+11
# 5440                              Software      ...        5.520150e+11
# 5429           Semiconductor Manufacturing      ...        5.510200e+11
# 5509           Semiconductor Manufacturing      ...        5.510200e+11
# 5286  Semiconductor Equipment and Services      ...        5.510300e+11
# 5340         Computer Hardware and Storage      ...        5.515200e+11
# 5335              Communications Equipment      ...        5.515150e+11
# 5096                              Software      ...        5.520150e+11
# 5442                              Software      ...        5.520150e+11
# 5128                              Software      ...        5.520150e+11
# 5057                              Software      ...        5.520150e+11
# 5423         Computer Hardware and Storage      ...        5.515200e+11
# 5098                              Software      ...        5.520150e+11
# 5221              Communications Equipment      ...        5.515150e+11
# 5222            Internet and Data Services      ...        5.520100e+11
# 5481            Internet and Data Services      ...        5.520100e+11
# 5027            Internet and Data Services      ...        5.520100e+11
# 5279              Communications Equipment      ...        5.515150e+11
# 5020           Semiconductor Manufacturing      ...        5.510200e+11
# 5396                 Electronic Components      ...        5.510100e+11
# 5201              Communications Equipment      ...        5.515150e+11
# 5508         Computer Hardware and Storage      ...        5.515200e+11
#
#                                            rbics_subind  msci_esg_env  \
# 5062                          Smart Phone Manufacturing           4.6
# 5038                      Web Search Sites and Software           5.8
# 5039                      Web Search Sites and Software           5.8
# 5325                    General and Mixed-Type Software           7.2
# 5202      Communication and Collaboration Content Sites           9.2
# 5262                Microprocessor (MPU) Semiconductors           7.5
# 5364             Diversified IT Infrastructure Software           7.3
# 5125                   General Communications Equipment           5.8
# 5264     General Information Technology (IT) Consulting           7.3
# 5359                    Video Multimedia Semiconductors           5.3
# 5449     General Analog and Mixed Signal Semiconductors           6.6
# 5397                Other Communications Semiconductors           3.9
# 5015     General Information Technology (IT) Consulting           7.0
# 5018         Multimedia Design and Engineering Software           3.9
# 5341  Media Download and Streaming Digital Content S...           5.3
# 5418         Diversified Customer Relationship Software           4.9
# 5063        Other Front End Processing Equipment Makers           5.2
# 5016                               Other Games Software           6.0
# 5324                     Volatile Memory Semiconductors           3.9
# 5417  Multi-Type Financial Data Content Providers/Sites          10.0
# 5133       Multi-Tactic Enterprise Solutions Consulting           3.8
# 5268                              Productivity Software           3.4
# 5253           Multi-Type Business and Personal Systems           4.4
# 5447                  Diversified Electronic Components           7.9
# 5055     General Analog and Mixed Signal Semiconductors           6.3
# 5181                             Console Games Software           8.0
# 5293        Other Front End Processing Equipment Makers           3.4
# 5173     General Information Technology (IT) Consulting           5.1
# 5053                 Electronic Interconnect Components           4.9
# 5498                Data Storage Drives and Peripherals           3.2
# 5070               Computer Aided Design (CAD) Software           5.0
# 5246     General Information Technology (IT) Consulting           5.3
# 5405             Diversified IT Infrastructure Software           3.9
# 5323                     Other Processor Semiconductors           4.6
# 5440                          Network Security Software           3.6
# 5429     General Analog and Mixed Signal Semiconductors           4.8
# 5509           Programmable Logic Device Semiconductors           4.8
# 5286  Semiconductor Process Analysis Tool Manufacturing           5.1
# 5340                               Disk Storage Systems           4.3
# 5335                           Other Wireless Equipment           3.2
# 5096                             Other Network Software           4.2
# 5442                IC-Level Electronic Design Software           4.5
# 5128                             Other Network Software           6.7
# 5057               Computer Aided Design (CAD) Software           4.0
# 5423                Data Storage Drives and Peripherals           4.0
# 5098              Other Design and Engineering Software           6.6
# 5221     Global Positioning Systems (GPS) Manufacturing           2.6
# 5222   General Professional Content Providers and Sites           2.8
# 5481                    Development and Design Services           7.5
# 5027                Colocation and Data Center Services          10.0
# 5279            General Carrier Edge (Access) Equipment           5.6
# 5020                Microprocessor (MPU) Semiconductors           4.2
# 5396  Other Module and Subassembly Electronic Compon...           4.6
# 5201          Carrier Edge Network Management Equipment           2.6
# 5508                   Printing and Imaging Peripherals           4.6
#
#      msci_esg_gov  msci_esg_social sales_total    sales_ps  sales_growth  \
# 5062          5.1              5.6  238799.000   43.523497      9.802236
# 5038          3.4              6.1  111024.000  157.797790     23.727057
# 5039          3.4              6.1  111024.000  157.797790     23.727057
# 5325          6.6              6.8   99547.000   11.414070     12.715559
# 5202          6.2              2.1   40653.000   13.752706     47.090962
# 5262          3.5              7.8   62761.000   12.980558      5.681378
# 5364          1.9              5.1   38905.000    8.946645      4.482222
# 5125          4.2              5.8   47789.000    9.507823     -2.305947
# 5264          2.6              6.9   79140.000   84.425233     -0.973498
# 5359          5.9              7.7    8976.000   10.647149     46.236559
# 5449          4.2              6.7   14961.000   14.783597     11.899776
# 5397          3.4              5.8   22360.000   14.960403     -5.963496
# 5015          7.6              7.6   37814.368   55.666200      7.009843
# 5018          4.8              6.3    7268.653   14.504728     25.016778
# 5341          1.7              4.1   11692.713   26.169084     32.410274
# 5418          4.9              6.6    9922.997   11.984833     25.490105
# 5063          6.8              6.6   14537.000   13.410517     34.290993
# 5016          3.4              3.6    7018.000    9.160574      6.220675
# 5324          5.9              3.6   23155.000   17.610052     77.855442
# 5417          4.8              1.9    6063.000   23.418308      7.101219
# 5133          5.7              4.7   14810.000   24.890756      9.808632
# 5268          5.5              5.8    5285.000   19.835249     11.052742
# 5253          6.1              5.7   52212.000   30.676851      8.283214
# 5447          4.7              4.6   13530.000   36.628492      8.517806
# 5055          4.6              5.2    5107.503   14.572714     49.280691
# 5181          6.6              2.2    5063.000   15.312102      9.969592
# 5293          7.1              7.4    9546.526   43.634097     49.547966
# 5173          3.8              4.0   20151.000   54.184771    167.787375
# 5053          4.4              4.7    7011.300   22.152607     11.531242
# 5498          5.0              3.9   20008.000   64.503378     25.686287
# 5070          6.5              5.7    1973.600    9.078581     -9.637837
# 5246          4.6              6.0   30286.000   17.287336    -12.071769
# 5405          7.2              4.0    2776.969   13.182061     19.364263
# 5323          4.6              4.7    3881.151   14.513288     26.719544
# 5440          4.4              5.6    4739.000    6.503236     25.469950
# 5429          3.8              6.6    3789.000   19.557579     15.641691
# 5509          7.1              5.3    2475.594    8.739644      7.124794
# 5286          4.7              3.5    3790.742   22.079921     16.173593
# 5340          6.1              3.4    5627.000   19.619217      4.242312
# 5335          5.7              5.3    6380.000   39.165132      5.664127
# 5096          5.4              5.2    4164.000    9.725301      3.248202
# 5442          3.8              3.3    2727.639   17.611988     12.196945
# 5128          4.7              4.2    2824.686   18.733948      3.238429
# 5057          4.2              4.0    1095.250   12.610242     10.803114
# 5423          8.0              4.1   10626.000   36.023411     -2.870201
# 5098          6.4              3.1    1943.032    6.933927      6.990264
# 5221          7.0              5.2    3089.968   16.356548      2.362037
# 5222          5.2              4.6    3311.494   36.880432     35.464914
# 5481          4.7              2.9    1165.095    9.382308      2.007412
# 5027          2.9              4.2    2502.996   14.492395      6.963401
# 5279          3.9              4.4    5027.200   13.084852      0.743472
# 5020          5.7              5.7    5523.000    5.128970     29.283708
# 5396          5.5              4.6    2951.145   23.855807     -1.551415
# 5201          6.7              4.5    2097.274   32.266168      3.748097
# 5508          4.9              5.1   10265.000   40.359203     -4.697800
#
#       rbics_sect_color  esg_combined
# 5062         firebrick     15.300000
# 5038               red     15.300000
# 5039               red     15.300000
# 5325               red     20.600000
# 5202               red     17.500000
# 5262           darkred     18.800000
# 5364               red     14.300000
# 5125         firebrick     15.800000
# 5264               red     16.800000
# 5359           darkred     18.900000
# 5449           darkred     17.500000
# 5397           darkred     13.100000
# 5015               red     22.200000
# 5018               red     15.000000
# 5341               red     11.100000
# 5418               red     16.400000
# 5063           darkred     18.600000
# 5016               red     13.000000
# 5324           darkred     13.400000
# 5417               red     16.700000
# 5133               red     14.200000
# 5268               red     14.700000
# 5253         firebrick     16.200000
# 5447           darkred     17.200000
# 5055           darkred     16.100000
# 5181               red     16.800000
# 5293           darkred     17.900000
# 5173               red     12.900000
# 5053           darkred     14.000000
# 5498         firebrick     12.100000
# 5070               red     17.200000
# 5246               red     15.900000
# 5405               red     15.100000
# 5323           darkred     13.900000
# 5440               red     13.600000
# 5429           darkred     15.200000
# 5509           darkred     17.200000
# 5286           darkred     13.300000
# 5340         firebrick     13.800000
# 5335         firebrick     14.200000
# 5096               red     14.800000
# 5442               red     11.600000
# 5128               red     15.599999
# 5057               red     12.200000
# 5423         firebrick     16.100000
# 5098               red     16.100000
# 5221         firebrick     14.800000
# 5222               red     12.600000
# 5481               red     15.100000
# 5027               red     17.100000
# 5279         firebrick     13.900000
# 5020           darkred     15.599999
# 5396           darkred     14.700000
# 5201         firebrick     13.800000
# 5508         firebrick     14.600000
#
# [55 rows x 24 columns]

# %%
hans_rosling_date_and_rbics('12/29/2017', 'Technology')

# %%
hans_rosling_date_and_rbics('12/30/2016', 'Technology')

# %%
hans_rosling_date_and_rbics('12/31/2015', 'Technology')

# %%
hans_rosling_date_and_rbics('12/31/2014', 'Technology')

# %%
hans_rosling_date_and_rbics('12/31/2013', 'Technology')

# %%
hans_rosling_date_and_rbics('12/31/2012', 'Technology')

# %%
hans_rosling_date_and_rbics('12/30/2011', 'Technology')

# %%
hans_rosling_date_and_rbics('12/31/2010', 'Technology')

# %%
hans_rosling_date_and_rbics('12/31/2009', 'Technology')

# %%
hans_rosling_date_and_rbics('12/31/2008', 'Technology')

# %%
hans_rosling_date_and_rbics('12/31/2007', 'Technology')
