# %% [markdown]
# # Data Visualization Project
#
# Open:FactSet Insights and Analysis team.
#
# The team mission is to educate, inspire, and empower FactSetters and clients to utilize Open:FactSet Data and Solutions.
#
# As part of the team you will be tasked with creating and communicating compelling stories for Marketplace content.  Secondarily, the team collective will need to develop best practices and methods for disseminating knowledge both internally and externally.  For the interview please prepare a 20-30 minute presentation covering:
#
# 1. For an audience of CTS Sales, create a presentation showcasing a FactSet content set using Python, R, or SQL.  The goal is to educate on potential applications, how a given technology is applied and how to pitch this to their client base.
#     - Python, Jupyter Notebook, Ondemand?,
#     - Unique Datasets - RBICs + ESG Data
#     - Exploratory Data Analysis
#     - Hans Rosling Chart

# %%
from pathlib import Path

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

#Increase default figure and font sizes for easier viewing.
plt.rcParams['figure.figsize'] = (16, 9)
plt.rcParams['font.size'] = 14

plt.style.use('fivethirtyeight')

# %%
data  = Path('.', 'assets', 'rbics_esg_data_m.csv')
hans_rosling = pd.read_csv(data, na_values= '@NA')

# %%
hans_rosling = hans_rosling.dropna()

# %%
hans_rosling.columns = ['Symbol', 'Name', 'Date', 'mkt_val', 'rbics_econn', 'rbics_econ',
       'rbics_sectn', 'rbics_sect', 'rbics_subsectn', 'rbics_subsect',
       'rbics_indgrpn', 'rbics_indgrp', 'rbics_indn', 'rbics_ind',
       'rbics_subindn', 'rbics_subind', 'msci_esg_env', 'msci_esg_gov',
       'msci_esg_social', 'sales_total', 'sales_ps', 'sales_growth',
       'msci_esg_score', 'msci_esg_rating']

# %%
# RBICS Econonmic Focus Color Map 
# source:  https://matplotlib.org/2.0.2/examples/color/named_colors.html

econ_color_dict = {
    'Non-Energy Materials': 'black', 
    'Industrials': 'white', 
    'Healthcare': 'gray', 
    'Technology': 'red',
    'Consumer Cyclicals': 'orange', 
    'Utilities': 'yellow', 
    'Finance': 'green',
    'Consumer Non-Cyclicals': 'blue', 
    'Energy': 'indigo', 
    'Telecommunications': 'violet',
    'Business Services': 'pink', 
    'Consumer Services': 'chocolate',
    'Other': 'black'
    
}

# %%
# RBICS Sector Focus Color Map
# source:  https://matplotlib.org/2.0.2/examples/color/named_colors.html

sect_color_dict = {
    'Manufactured Products': 'black', 
    'Industrial Manufacturing': 'white',
    'Healthcare Equipment': 'lightgray', 
    'Biopharmaceuticals': 'gray',
    'Software and Consulting': 'red', 
    'Miscellaneous Retail': 'darkorange',
    'Electronic Components and Manufacturing': 'darkred', 
    'Utilities': 'yellow',
    'Healthcare Services': 'silver', 
    'Investment Services': 'lawngreen', 
    'Insurance': 'green',
    'Chemical, Plastic and Rubber Materials': 'k', 
    'Real Estate': 'seagreen',
    'Mining and Mineral Products': 'dimgray', 
    'Specialty Finance and Services': 'darkolivegreen',
    'Food and Tobacco Production': 'blue', 
    'Food and Staples Retail': 'dodgerblue',
    'Industrial Services': 'whitesmoke', 
    'Upstream Energy': 'indigo',
    'Downstream and Midstream Energy': 'blueviolet', 
    'Hardware': 'firebrick',
    'Consumer Vehicles and Parts': 'peachpuff', 
    'Telecommunications': 'violet',
    'Business Services': 'pink', 
    'Banking': 'forestgreen', 
    'Consumer Retail': 'orange',
    'Hospitality Services': 'sienna', 
    'Media and Publishing Services': 'saddlebrown',
    'Household Products': 'navy', 
    'Household Services': 'royalblue',
    'Consumer Goods': 'sandybrown',
    'General or Multi-Industry Revenue': 'black'
    
}

# %%
# Sum ESG Scores for Environment + Social + Government
hans_rosling.loc[:, 'rbics_sect_color'] = hans_rosling.loc[:, 'rbics_sect'].map(sect_color_dict)
#hans_rosling.loc[:, 'esg_combined'] = hans_rosling.loc[:, ['msci_esg_env','msci_esg_social', 'msci_esg_gov']].sum(axis=1)

# %%
def hans_rosling_date_and_rbics(year, econ):
    #Define a function that creates a scatter plot based on x = esg_score, y = sales_total, size = mkt_val, color = rbics_sector
    #Filter by date and rbics econ
    
    # Define a function that filters the dataframe by date    
    date_filter = hans_rosling.loc[:, 'Date'] == year
    hans_rosling_year = hans_rosling.loc[date_filter, :]
    
    # filter by rbics_sect
    rbics_filter = hans_rosling_year.loc[:, 'rbics_econ'] == econ
    hans_rosling_year_and_rbics = hans_rosling_year.loc[rbics_filter, :]
    
    
    #store values into array variables for scatter plot
    esg_score = hans_rosling_year_and_rbics.loc[:, 'msci_esg_score']
    sales = hans_rosling_year_and_rbics.loc[:, 'sales_total']
    mktval = hans_rosling_year_and_rbics.loc[:, 'mkt_val']
    rbics = hans_rosling_year_and_rbics.loc[:, 'rbics_econ']
    rbics_color = hans_rosling_year_and_rbics.loc[:, 'rbics_sect_color']
    ticker = hans_rosling_year_and_rbics.loc[:, 'Symbol']
    
    # Store Symbol and coordinates for select Companies into a dictionary
    # Dictionary is used for better error handling when Company does not exist in the chart
    my_dict = {}

    for symbol in ['FB', 'AMZN', 'AAPL', 'NFLX', 'GOOG', 'BRK.B', 'WMT', 'XOM',
                   'MSFT','DIS', 'TWX', 'FOX', 'PG', 'BA', 'GE', 'JNJ', 'UNH',
                   'HD', 'NKE', 'GM', 'DUK', 'JPM', 'V', 'GS', 'KO', 'MO',
                   'CVX', 'T', 'VZ', 'ADP']:
        symbol_filter = hans_rosling_year_and_rbics.loc[:, 'Symbol'] == symbol
        label = np.array((hans_rosling_year_and_rbics.loc[symbol_filter, ['msci_esg_score', 'sales_total']]))
        if label.size >1:
            my_dict.update({symbol: (label[0][0], label[0][1])})
    
    
    # Scatter plot
    plt.scatter(x = esg_score, y = sales, s = mktval/100 , edgecolors='black', c = rbics_color, alpha=.75)

    
    # customizations
    plt.yscale('log')
    plt.xlabel('ESG Score')
    plt.ylabel('Revenue')
    plt.xlim(-1,11)
    plt.ylim(500, 700000)
    plt.title(year)
    plt.yticks([1000,10000,100000], ['1b','10b','100b'])

    
    # Adding Labels for Symbol, ESG score, and Sales Total
    for key, value in my_dict.items():
        plt.text(value[0], value[1], key)
    
    
    # Add grid() 
    plt.grid(True)

    
    # return and display the plot
    return plt.show()

# %%
# Define a function that filters the dataframe by date    
date_filter = hans_rosling.loc[:, 'Date'] == '12/31/2017'
hans_rosling_year = hans_rosling.loc[date_filter, :]

# filter by rbics_sect
rbics_filter = hans_rosling_year.loc[:, 'rbics_econ'] == 'Technology'
# 18179                  Software and Consulting        552010.0
# 18465                  Software and Consulting        552015.0
# 18342                  Software and Consulting        552010.0
# 18402  Electronic Components and Manufacturing        551020.0
# 18504                  Software and Consulting        552015.0
# 18265                                 Hardware        551515.0
# 18404                  Software and Consulting        552020.0
# 18499  Electronic Components and Manufacturing        551020.0
# 18589  Electronic Components and Manufacturing        551020.0
# 18537  Electronic Components and Manufacturing        551020.0
# 18155                  Software and Consulting        552020.0
# 18158                  Software and Consulting        552015.0
# 18481                  Software and Consulting        552010.0
# 18558                  Software and Consulting        552015.0
# 18203  Electronic Components and Manufacturing        551030.0
# 18156                  Software and Consulting        552015.0
# 18464  Electronic Components and Manufacturing        551020.0
# 18557                  Software and Consulting        552010.0
# 18273                  Software and Consulting        552020.0
# 18408                  Software and Consulting        552015.0
# 18393                                 Hardware        551520.0
# 18587  Electronic Components and Manufacturing        551010.0
# 18195  Electronic Components and Manufacturing        551020.0
# 18321                  Software and Consulting        552015.0
# 18433  Electronic Components and Manufacturing        551030.0
# 18313                  Software and Consulting        552020.0
# 18193  Electronic Components and Manufacturing        551010.0
# 18638                                 Hardware        551520.0
# 18210                  Software and Consulting        552015.0
# 18386                  Software and Consulting        552020.0
# 18545                  Software and Consulting        552015.0
# 18463  Electronic Components and Manufacturing        551020.0
# 18580                  Software and Consulting        552015.0
# 18569  Electronic Components and Manufacturing        551020.0
# 18649  Electronic Components and Manufacturing        551020.0
# 18426  Electronic Components and Manufacturing        551030.0
# 18480                                 Hardware        551520.0
# 18475                                 Hardware        551515.0
# 18236                  Software and Consulting        552015.0
# 18582                  Software and Consulting        552015.0
# 18268                  Software and Consulting        552015.0
# 18197                  Software and Consulting        552015.0
# 18563                                 Hardware        551520.0
# 18238                  Software and Consulting        552015.0
# 18361                                 Hardware        551515.0
# 18362                  Software and Consulting        552010.0
# 18621                  Software and Consulting        552010.0
# 18167                  Software and Consulting        552010.0
# 18419                                 Hardware        551515.0
# 18160  Electronic Components and Manufacturing        551020.0
# 18536  Electronic Components and Manufacturing        551010.0
# 18341                                 Hardware        551515.0
# 18648                                 Hardware        551520.0
#
#                               rbics_subsect        ...         \
# 18202              Communications Equipment        ...
# 18178            Internet and Data Services        ...
# 18179            Internet and Data Services        ...
# 18465                              Software        ...
# 18342            Internet and Data Services        ...
# 18402           Semiconductor Manufacturing        ...
# 18504                              Software        ...
# 18265              Communications Equipment        ...
# 18404        Technology Consulting Services        ...
# 18499           Semiconductor Manufacturing        ...
# 18589           Semiconductor Manufacturing        ...
# 18537           Semiconductor Manufacturing        ...
# 18155        Technology Consulting Services        ...
# 18158                              Software        ...
# 18481            Internet and Data Services        ...
# 18558                              Software        ...
# 18203  Semiconductor Equipment and Services        ...
# 18156                              Software        ...
# 18464           Semiconductor Manufacturing        ...
# 18557            Internet and Data Services        ...
# 18273        Technology Consulting Services        ...
# 18408                              Software        ...
# 18393         Computer Hardware and Storage        ...
# 18587                 Electronic Components        ...
# 18195           Semiconductor Manufacturing        ...
# 18321                              Software        ...
# 18433  Semiconductor Equipment and Services        ...
# 18313        Technology Consulting Services        ...
# 18193                 Electronic Components        ...
# 18638         Computer Hardware and Storage        ...
# 18210                              Software        ...
# 18386        Technology Consulting Services        ...
# 18545                              Software        ...
# 18463           Semiconductor Manufacturing        ...
# 18580                              Software        ...
# 18569           Semiconductor Manufacturing        ...
# 18649           Semiconductor Manufacturing        ...
# 18426  Semiconductor Equipment and Services        ...
# 18480         Computer Hardware and Storage        ...
# 18475              Communications Equipment        ...
# 18236                              Software        ...
# 18582                              Software        ...
# 18268                              Software        ...
# 18197                              Software        ...
# 18563         Computer Hardware and Storage        ...
# 18238                              Software        ...
# 18361              Communications Equipment        ...
# 18362            Internet and Data Services        ...
# 18621            Internet and Data Services        ...
# 18167            Internet and Data Services        ...
# 18419              Communications Equipment        ...
# 18160           Semiconductor Manufacturing        ...
# 18536                 Electronic Components        ...
# 18341              Communications Equipment        ...
# 18648         Computer Hardware and Storage        ...
#
#                                             rbics_subind msci_esg_env  \
# 18202                          Smart Phone Manufacturing          4.6
# 18178                      Web Search Sites and Software          5.8
# 18179                      Web Search Sites and Software          5.8
# 18465                    General and Mixed-Type Software          7.2
# 18342      Communication and Collaboration Content Sites          9.2
# 18402                Microprocessor (MPU) Semiconductors          7.5
# 18504             Diversified IT Infrastructure Software          7.3
# 18265                   General Communications Equipment          5.8
# 18404     General Information Technology (IT) Consulting          7.3
# 18499                    Video Multimedia Semiconductors          5.3
# 18589     General Analog and Mixed Signal Semiconductors          6.6
# 18537                Other Communications Semiconductors          3.9
# 18155     General Information Technology (IT) Consulting          7.0
# 18158         Multimedia Design and Engineering Software          3.9
# 18481  Media Download and Streaming Digital Content S...          5.3
# 18558         Diversified Customer Relationship Software          4.9
# 18203        Other Front End Processing Equipment Makers          5.2
# 18156                               Other Games Software          6.0
# 18464                     Volatile Memory Semiconductors          3.9
# 18557  Multi-Type Financial Data Content Providers/Sites         10.0
# 18273       Multi-Tactic Enterprise Solutions Consulting          3.8
# 18408                              Productivity Software          3.4
# 18393           Multi-Type Business and Personal Systems          4.4
# 18587                  Diversified Electronic Components          7.9
# 18195     General Analog and Mixed Signal Semiconductors          6.3
# 18321                             Console Games Software          8.0
# 18433        Other Front End Processing Equipment Makers          3.4
# 18313     General Information Technology (IT) Consulting          5.1
# 18193                 Electronic Interconnect Components          4.9
# 18638                Data Storage Drives and Peripherals          3.2
# 18210               Computer Aided Design (CAD) Software          5.0
# 18386     General Information Technology (IT) Consulting          5.3
# 18545             Diversified IT Infrastructure Software          3.9
# 18463                     Other Processor Semiconductors          4.6
# 18580                          Network Security Software          3.6
# 18569     General Analog and Mixed Signal Semiconductors          4.8
# 18649           Programmable Logic Device Semiconductors          4.8
# 18426  Semiconductor Process Analysis Tool Manufacturing          5.1
# 18480                               Disk Storage Systems          4.3
# 18475                           Other Wireless Equipment          3.2
# 18236                             Other Network Software          4.2
# 18582                IC-Level Electronic Design Software          4.5
# 18268                             Other Network Software          6.7
# 18197               Computer Aided Design (CAD) Software          4.0
# 18563                Data Storage Drives and Peripherals          4.0
# 18238              Other Design and Engineering Software          6.6
# 18361     Global Positioning Systems (GPS) Manufacturing          2.6
# 18362           5.2             4.6     3311.494   36.880432     35.464914
# 18621           4.7             2.9     1165.095    9.382308      2.007412
# 18167           2.9             4.2     2494.052   14.492395      6.581187
# 18419           3.9             4.4     5027.200   13.084852      0.743472
# 18160           5.7             5.7     5523.000    5.128970     29.283708
# 18536           5.5             4.6     2951.145   23.855807     -1.551415
# 18341           6.7             4.5     2097.274   32.266168      3.748097
# 18648           4.9             5.1    10265.000   40.359203     -4.697800
#
#        msci_esg_score  msci_esg_rating  rbics_sect_color
# 18202             7.1                A         firebrick
# 18178             6.5                A               red
# 18179             6.5                A               red
# 18465            10.0              AAA               red
# 18342             5.7              BBB               red
# 18402             8.2               AA           darkred
# 18504             6.7                A               red
# 18265             7.1                A         firebrick
# 18404             8.1               AA               red
# 18499             7.7               AA           darkred
# 18589             7.4               AA           darkred
# 18537             1.9                B           darkred
# 18155            10.0              AAA               red
# 18158             7.0                A               red
# 18481             3.1               BB               red
# 18558             8.4               AA               red
# 18203             6.8                A           darkred
# 18156             3.2               BB               red
# 18464             1.6                B           darkred
# 18557             5.6              BBB               red
# 18273             6.5                A               red
# 18408             7.6               AA               red
# 18393             7.5               AA         firebrick
# 18587             7.9               AA           darkred
# 18195             5.2              BBB           darkred
# 18321             4.1               BB               red
# 18433             6.8                A           darkred
# 18313             5.4              BBB               red
# 18193             4.8              BBB           darkred
# 18638             1.8                B         firebrick
# 18210             8.1               AA               red
# 18386             8.2               AA               red
# 18545             5.7              BBB               red
# 18463             4.4              BBB           darkred
# 18580             7.0                A               red
# 18569             5.2              BBB           darkred
# 18649             4.2               BB           darkred
# 18426             3.8               BB           darkred
# 18480             3.6               BB         firebrick
# 18475             6.8                A         firebrick
# 18236             7.0                A               red
# 18582             3.5               BB               red
# 18268             6.8                A               red
# 18197             4.6              BBB               red
# 18563             5.7              BBB         firebrick
# 18238             8.4               AA               red
# 18361             5.2              BBB         firebrick
# 18362             5.7              BBB               red
# 18621             4.1               BB               red
# 18167             4.9              BBB               red
# 18419             5.0              BBB         firebrick
# 18160             4.6              BBB           darkred
# 18536             3.3               BB           darkred
# 18341             5.7              BBB         firebrick
# 18648             6.8                A         firebrick
#
# [55 rows x 25 columns]

# %%
hans_rosling.Date.unique()
# Out:
# array(['12/31/2014', ' 1/31/2015', ' 2/28/2015', ' 3/31/2015',
#        ' 4/30/2015', ' 5/31/2015', ' 6/30/2015', ' 7/31/2015',
#        ' 8/31/2015', ' 9/30/2015', '10/31/2015', '11/30/2015',
#        '12/31/2015', ' 1/31/2016', ' 2/29/2016', ' 3/31/2016',
#        ' 4/30/2016', ' 5/31/2016', ' 6/30/2016', ' 7/31/2016',
#        ' 8/31/2016', ' 9/30/2016', '10/31/2016', '11/30/2016',
#        '12/31/2016', ' 1/31/2017', ' 2/28/2017', ' 3/31/2017',
#        ' 4/30/2017', ' 5/31/2017', ' 6/30/2017', ' 7/31/2017',
#        ' 8/31/2017', ' 9/30/2017', '10/31/2017', '11/30/2017', '12/31/2017'], dtype=object)

# %%
for date in hans_rosling.Date.unique():
    hans_rosling_date_and_rbics(date, 'Energy')
