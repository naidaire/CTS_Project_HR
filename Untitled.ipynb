# %% [markdown]
# # Data Visualization Project
#
# Open:FactSet Insights and Analysis team.
#
# The team mission is to educate, inspire, and empower FactSetters and clients to utilize Open:FactSet Data and Solutions.
#
# As part of the team you will be tasked with creating and communicating compelling stories for Marketplace content.  Secondarily, the team collective will need to develop best practices and methods for disseminating knowledge both internally and externally.  For the interview please prepare a 20-30 minute presentation covering:
#
# 1. For an audience of CTS Sales, create a presentation showcasing a FactSet content set using Python, R, or SQL.  The goal is to educate on potential applications, how a given technology is applied and how to pitch this to their client base.
#     - Python, Jupyter Notebook, Ondemand?,
#     - Unique Datasets - RBICs + SCG Data
#     - Exploratory Data Analysis
#     - Hans Rosling Chart

# %% [markdown]
# 2. Present an idea of how the Insights and Analysis team can approach educating, inspiring, or empowering FactSetters and clients in FY19.
#     - Code-along programs
#     - package together internet resources for people interested in learning
#     - Newsletters + sharing of code, methodology, and data.  Make sure it's error-free documentation
#     - Github for sharing and distributing across the firm
#     - Get all teams involved in Machine Learning involved in an initiative to teach Data Science and Analysis techniques across the firm
#     - Phase 1 team - Jupyter, Publish in Marketplace, Story-telling with EDA
#     - Phase 2 team - d3.js - more interactive datavisualization tools
#     - Conferences: Jupyter Conference, Tableau Conference, etc...
#     - FactSet Surveys to collect unique content

# %% [markdown]
# Create a Hans Rosling Chart.
#
# Hypothesis:
# - Analyze the impact of ESG Data, Market Cap, and Revenue on S&P500 stocks against other companies in the same revere classification
# - does the Rich get richer while the Poor get poorer?
# - Hypothesize that the growth of FAANG has meant areas of growth for other companies in their Revere Sectors
#
#
# Extract and Perform EDA
# - Scatter Plot data points = Company
# - X = **Revenue**, Growth Rate
# - Y = # of Employees, Revenue, **GDPR**
#
# - Time Series - plotted individually
# - Size = Market Capitalization
# - Color = Revere Classification

# %% [markdown]
# # Importing Data

# %%
from pathlib import Path

import matplotlib.pyplot as plt
import pandas as pd

# %%
#Increase default figure and font sizes for easier viewing.
plt.rcParams['figure.figsize'] = (12, 10)
plt.rcParams['font.size'] = 14

plt.style.use('fivethirtyeight')

# %%
data  = Path('.', 'assets', 'rbics_esg_data.csv')
hans_rosling = pd.read_csv(data, na_values= '-')

# %% [markdown]
# # Cleaning Data

# %%
hans_rosling = hans_rosling.dropna()

# %%
hans_rosling.shape
# Out:
# (4983, 22)

# %%
hans_rosling.columns
# Out:
# Index(['Symbol', 'Name', 'Date', 'mkt_val', 'rbics_econn', 'rbics_econ',
#        'rbics_sectn', 'rbics_sect', 'rbics_subsectn', 'rbics_subsect',
#        'rbics_indgrpn', 'rbics_indgrp', 'rbics_indn', 'rbics_ind',
#        'rbics_subindn', 'rbics_subind', 'msci_esg_env', 'msci_esg_gov',
#        'msci_esg_social', 'sales_total', 'sales_ps', 'sales_growth'],
#       dtype='object')

# %%
hans_rosling.describe()
# Out:
#              mkt_val  rbics_econn  rbics_sectn  rbics_subsectn  rbics_indgrpn  \
# count    4983.000000  4983.000000  4983.000000     4983.000000   4.983000e+03
# mean    32471.736657    37.826610  3797.203492   379735.251856   3.797354e+07
# std     58030.195997    14.453529  1444.701150   144470.621376   1.444706e+07
# min       488.724000    10.000000  1010.000000   101010.000000   1.010101e+07
# 25%      8073.439694    30.000000  3010.000000   301020.000000   3.010201e+07
# 50%     14523.537590    35.000000  3520.000000   352015.000000   3.520151e+07
# 75%     29972.717240    50.000000  5015.000000   501515.000000   5.015152e+07
# max    859967.798700    65.000000  6510.000000   651015.000000   6.510152e+07
#
#          rbics_indn  rbics_subindn  msci_esg_env  msci_esg_gov  \
# count  4.983000e+03   4.983000e+03   4983.000000   4983.000000
# mean   3.797354e+09   3.797353e+11      5.217700      5.546189
# std    1.444706e+09   1.444706e+11      2.065567      1.997506
# min    1.010101e+09   1.010100e+11      0.000000      0.000000
# 25%    3.010201e+09   3.010200e+11      3.900000      4.300000
# 50%    3.520151e+09   3.520150e+11      5.100000      5.300000
# 75%    5.015152e+09   5.015150e+11      6.500000      6.620000
# max    6.510152e+09   6.510150e+11     10.000000     10.000000
#
#        msci_esg_social    sales_total     sales_ps  sales_growth
# count      4983.000000    4983.000000  4983.000000   4983.000000
# mean          4.647524   20779.758198    44.907485      5.691396
# std           1.759109   38960.931508    89.397126     21.479874
# min           0.000000     533.901000     1.528933    -78.120102
# 25%           3.450000    4185.099000    14.128801     -1.842704
# 50%           4.620000    8783.600000    25.737466      4.280139
# 75%           5.780000   18654.500000    47.063297     11.053337
# max          10.000000  495012.000000  2589.251212    846.495580

# %% [markdown]
# # Chart for 2017

# %%
#filter by Date for 2017
date = hans_rosling.loc[:, 'Date'] == '12/29/2017'
hans_rosling_2017 = hans_rosling.loc[date, :]

# %%
hans_rosling_2017.head()
# Out:
#      Symbol                     Name        Date       mkt_val  rbics_econn  \
# 5011    MMM               3M Company  12/29/2017  140017.90290         45.0
# 5012    AOS  A. O. Smith Corporation  12/29/2017   10519.51661         40.0
# 5013    ABT      Abbott Laboratories  12/29/2017   99507.39291         35.0
# 5014   ABBV             AbbVie, Inc.  12/29/2017  153974.99140         35.0
# 5015    ACN    Accenture Plc Class A  12/29/2017   94206.00357         55.0
#
#                 rbics_econ  rbics_sectn                rbics_sect  \
# 5011  Non-Energy Materials       4520.0     Manufactured Products
# 5012           Industrials       4010.0  Industrial Manufacturing
# 5013            Healthcare       3520.0      Healthcare Equipment
# 5014            Healthcare       3510.0        Biopharmaceuticals
# 5015            Technology       5520.0   Software and Consulting
#
#       rbics_subsectn                       rbics_subsect      ...       \
# 5011        452020.0                     Other Materials      ...
# 5012        401020.0             Machinery Manufacturing      ...
# 5013        352015.0             General Medical Devices      ...
# 5014        351020.0  System-Specific Biopharmaceuticals      ...
# 5015        552020.0      Technology Consulting Services      ...
#
#         rbics_indn                                          rbics_ind  \
# 5011  4.520202e+09                              Diversified Materials
# 5012  4.010201e+09  Environmental Control Machinery/Equipment Prod...
# 5013  3.520152e+09        Diversified Medical Devices and Instruments
# 5014  3.510204e+09            Autoimmune Disorders Biopharmaceuticals
# 5015  5.520202e+09                  Information Technology Consulting
#
#       rbics_subindn                                       rbics_subind  \
# 5011   4.520200e+11                              Diversified Materials
# 5012   4.010200e+11  Heating, Ventilation and Air Conditioning Prod...
# 5013   3.520150e+11        Diversified Medical Devices and Instruments
# 5014   3.510200e+11            Autoimmune Disorders Biopharmaceuticals
# 5015   5.520200e+11     General Information Technology (IT) Consulting
#
#       msci_esg_env msci_esg_gov  msci_esg_social  sales_total   sales_ps  \
# 5011           7.1          6.2              5.2    31657.000  51.668027
# 5012           6.6          4.2              4.2     2996.700  17.162720
# 5013          10.0          3.5              4.0    27390.000  15.660377
# 5014           5.6          4.9              4.7    28216.000  17.601996
# 5015           7.0          7.6              7.6    37814.368  55.666200
#
#       sales_growth
# 5011      5.141320
# 5012     11.571540
# 5013     31.348007
# 5014     10.055387
# 5015      7.009843
#
# [5 rows x 22 columns]

# %%
# Analyze the impact of ESG Data, Market Cap, 
# and Revenue on S&P500 stocks against other companies in the same revere classification

# %%
esg_env = hans_rosling_2017.loc[:, 'msci_esg_env']

# %%
sales = hans_rosling_2017.loc[:, 'sales_total']

# %%
mktval = hans_rosling_2017.loc[:, 'mkt_val']

# %%
rbics = hans_rosling_2017.loc[:, 'rbics_econ']

# %%
# Sample Code from DataCamp Program

# Scatter plot
plt.scatter(x = esg_env, y = sales, s = mktval/100 , alpha=.5)

# Previous customizations
#plt.xscale('log')
plt.yscale('log')
plt.xlabel('ESG env data')
plt.ylabel('Revenue')
plt.title('2017')
#plt.xticks([1000,10000,100000], ['1k','10k','100k'])

# Additional customizations
#plt.text(1550, 71, 'India')
#plt.text(5700, 80, 'China')

# Add grid() call
plt.grid(True)

# Show the plot
plt.show()

# %%
hans_rosling_2017.loc[:, 'rbics_sect'].unique()
# Out:
# array(['Manufactured Products', 'Industrial Manufacturing',
#        'Healthcare Equipment', 'Biopharmaceuticals',
#        'Software and Consulting', 'Miscellaneous Retail',
#        'Electronic Components and Manufacturing', 'Utilities',
#        'Healthcare Services', 'Investment Services', 'Insurance',
#        'Chemical, Plastic and Rubber Materials', 'Real Estate',
#        'Mining and Mineral Products', 'Specialty Finance and Services',
#        'Food and Tobacco Production', 'Food and Staples Retail',
#        'Industrial Services', 'Upstream Energy',
#        'Downstream and Midstream Energy', 'Hardware',
#        'Consumer Vehicles and Parts', 'Telecommunications',
#        'Business Services', 'Banking', 'Consumer Retail',
#        'Hospitality Services', 'Media and Publishing Services',
#        'Household Products', 'Consumer Goods'], dtype=object)

# %%
hans_rosling_2017.loc[:, 'rbics_subsect'].unique()
# Out:
# array(['Other Materials', 'Machinery Manufacturing',
#        'General Medical Devices', 'System-Specific Biopharmaceuticals',
#        'Technology Consulting Services', 'Software',
#        'Electrical Equipment and Power Systems', 'Auto Retail',
#        'Semiconductor Manufacturing', 'Energy Utilities',
#        'Healthcare Support Services', 'Investment Services', 'Insurance',
#        'Miscellaneous Healthcare', 'Commodity Chemicals',
#        'Internet and Data Services', 'Specialty and Performance Chemicals',
#        'Real Estate Investment Trusts (REITs)', 'Other Medical Devices',
#        'Metal Products', 'Other Biopharmaceuticals', 'Specialty Finance',
#        'Tobacco Production', 'General Merchandise Retail',
#        'Passenger Transportation', 'Water Utilities',
#        'Electronic Components', 'Fossil Fuel Exploration and Production',
#        'Downstream Energy', 'Communications Equipment',
#        'Semiconductor Equipment and Services',
#        'Consumer Vehicles and Parts', 'Agriculture',
#        'Aerospace and Defense Manufacturing',
#        'Other Telecommunications Services', 'Other Professional Services',
#        'Containers and Packaging',
#        'Support Activities for Oil and Gas Operations',
#        'United States Banks', 'Electronics and Entertainment Retail',
#        'Food and Beverage Production', 'Delivery and Logistics Services',
#        'Hospitality Services', 'Real Estate Investment and Services',
#        'Media and Publishing Services',
#        'Non-System-Specific Biopharmaceuticals',
#        'Wireless and Wireline Telecommunications Services',
#        'Personal Care and Cleaning Products', 'Business Support Services',
#        'Minerals', 'Cargo Transportation and Infrastructure Services',
#        'Transportation Equipment Manufacturing',
#        'Health and Personal Care Retail',
#        'Home Builders and Manufactured Buildings', 'Patient Care',
#        'Diversified Industrials Distribution',
#        'Facilities and Construction Services',
#        'Apparel and Accessories Retail', 'Household Products',
#        'Metal Ore Mining', 'Apparel and Accessory Products',
#        'Leisure Goods Products', 'Home Improvement Retail',
#        'Computer Hardware and Storage', 'Marketing and Printing Services',
#        'Outsourced Development and Manufacturing Services',
#        'Midstream Energy', 'Food and Beverage Retail', 'Mixed Chemicals',
#        'Construction Materials', 'Waste Management Services',
#        'Household Appliances and Furnishings Production'], dtype=object)
